# %% [markdown]
# #Web Scraping using BeautifulSoup

# %% [markdown]
# The aim is to scrape a website and convert the data extracted into a csv file

# %% [markdown]
# ##Hacker News
#
# The website selected for the scraping is a tech-news website, which contains daily news articles about various technologies.
# * The main webpage of the site contains titles, links and the votes which are given by the readers.
#
# * We are going to scrape the website for the titles of the articles and their respective links and votes.
#
# * We are going to sort the articles bases on the highest votes polled.

# %%
import requests
from bs4 import BeautifulSoup
import pprint
#res is request to get the first page of the website
res = requests.get('https://news.ycombinator.com/news')
#res2 is the request the second page of the website
res2 = requests.get('https://news.ycombinator.com/news?p=2')
soup = BeautifulSoup(res.text, 'html.parser')
soup2 = BeautifulSoup(res2.text, 'html.parser')

links = soup.select('.titlelink') #.titlelink
#Subtext of the title of first page
subtext = soup.select('.subtext')
# titles and subtexts of the second page
links2 = soup2.select('.titlelink') #.titlelink
subtext2 = soup2.select('.subtext')
# appending the links and subtexts we obtained
mega_links = links + links2
mega_subtext = subtext + subtext2

# Sorting the articles based on the highest votes
def sort_stories_by_votes(hnlist):
  return sorted(hnlist, key= lambda k:k['votes'], reverse=True)

# Creating an array of the dictionaries formed by the titles, links and votes
def create_custom_hn(links, subtext):
  hn = []
  for idx, item in enumerate(links):
    title = item.getText()
    href = item.get('href', None)
    vote = subtext[idx].select('.score')
    if len(vote):
      points = int(vote[0].getText().replace(' points', ''))
      if points > 99:
        hn.append({'title': title, 'link': href, 'votes': points})
  return sort_stories_by_votes(hn)
 
pprint.pprint(create_custom_hn(mega_links, mega_subtext))
# Out:
# [{'link': 'https://bert.org/2022/06/02/payphone/',
#   'title': 'Installing a payphone in my house',
#   'votes': 1002},
#  {'link': 'https://vscodium.com/',
#   'title': 'VSCodium – Free/Libre Open Source Software Binaries of VS Code',
#   'votes': 657},
#  {'link': 'https://hirrolot.github.io/posts/rust-is-hard-or-the-misery-of-mainstream-programming.html',
#   'title': 'Rust Is Hard, Or: The Misery of Mainstream Programming',
#   'votes': 498},
#  {'link': 'https://www.webosarchive.com',
#   'title': "Show HN: I restored Palm's webOS App Catalog, SDK and online help "
#            'system',
#   'votes': 405},
#  {'link': 'https://www.tbray.org/ongoing/When/202x/2022/06/02/Dangerous-Gift',
#   'title': 'Dangerous Gift',
#   'votes': 308},
#  {'link': 'https://www.zkcrush.xyz/',
#   'title': 'Confess your love with zero-knowledge',
#   'votes': 279},
#  {'link': 'https://ukdefencejournal.org.uk/classified-specs-leaked-on-war-thunder-forum-for-third-time/',
#   'title': 'Classified specs leaked on War Thunder forum for third time',
#   'votes': 259},
#  {'link': 'https://www.dcrainmaker.com/2022/05/shimano-forces-hammerhead-to-remove-all-di2-related-functionality-from-karoo.html',
#   'title': 'Shimano Forces Hammerhead to Remove All Di2 Related Functionality '
#            'From Karoo',
#   'votes': 246},
#  {'link': 'https://www.jefftk.com/p/ceiling-air-purifier',
#   'title': 'Ceiling Air Purifier',
#   'votes': 245},
#  {'link': 'https://itsallaboutthebit.com/async-simple/',
#   'title': "Async Rust doesn't have to be hard",
#   'votes': 226},
#  {'link': 'https://www.epsilonsworld.com/2022/05/my-mega-65-has-arrived.html',
#   'title': 'My Mega65 has arrived',
#   'votes': 209},
#  {'link': 'https://blog.iconfactory.com/2022/06/worldwideweb-part-2/',
#   'title': 'WorldWideWeb.app',
#   'votes': 201},
#  {'link': 'https://yep.com',
#   'title': 'Yep: Google alternative that shares revenue with creators – by '
#            'Ahrefs',
#   'votes': 194},
#  {'link': 'https://www.stat.berkeley.edu/~aldous/Real-World/coin_tosses.html',
#   'title': '40k coin tosses yield ambiguous evidence for dynamical bias',
#   'votes': 173},
#  {'link': 'https://www.spamresource.com/2020/11/honestly-dont-send-to-gmail-over-ipv6.html',
#   'title': "Don't send to Gmail over IPv6",
#   'votes': 156},
#  {'link': 'https://www.latimes.com/food/story/2022-06-02/gas-stove-ban-chinese-korean-bbq-electric-new-buildings-restaurants-future',
#   'title': 'What a gas stove ban means for restaurants',
#   'votes': 151},
#  {'link': 'https://www.economist.com/united-states/2022/06/02/why-americans-are-poorly-served-by-their-grocery-stores',
#   'title': 'Americans are poorly served by their grocery stores',
#   'votes': 129},
#  {'link': 'https://courses.dibya.online/p/fastdeeprl',
#   'title': 'Show HN: Fast Deep Reinforcement Learning Course',
#   'votes': 128},
#  {'link': 'https://gpt-4chan.com/', 'title': 'GPT-4chan', 'votes': 119},
#  {'link': 'https://www.washingtonpost.com/travel/2022/06/02/last-howard-johnson-restaurant-closes/',
#   'title': "The last Howard Johnson's restaurant closes in Lake George, N.Y.",
#   'votes': 106},
#  {'link': 'https://semantle.com/',
#   'title': 'Semantle: guess words based on Word2vec similarity scores',
#   'votes': 104},
#  {'link': 'https://www.quantamagazine.org/brain-signal-proteins-evolved-before-animals-did-20220603/',
#   'title': 'Brain-signal proteins evolved before animals did',
#   'votes': 103},
#  {'link': 'https://archive.org/details/softwarelibrary_msdos_games',
#   'title': 'Software Library: MS-DOS Games',
#   'votes': 100}]

# %%
import pandas as pd
df = pd.DataFrame(create_custom_hn(mega_links, mega_subtext))
df
# Out:
#                                                 title  \
# 0                   Installing a payphone in my house
# 1   VSCodium – Free/Libre Open Source Software Bin...
# 2   Rust Is Hard, Or: The Misery of Mainstream Pro...
# 3   Show HN: I restored Palm's webOS App Catalog, ...
# 4                                      Dangerous Gift
# 5               Confess your love with zero-knowledge
# 6   Classified specs leaked on War Thunder forum f...
# 7   Shimano Forces Hammerhead to Remove All Di2 Re...
# 8                                Ceiling Air Purifier
# 9                  Async Rust doesn't have to be hard
# 10                              My Mega65 has arrived
# 11                                   WorldWideWeb.app
# 12  Yep: Google alternative that shares revenue wi...
# 13  40k coin tosses yield ambiguous evidence for d...
# 14                      Don't send to Gmail over IPv6
# 15         What a gas stove ban means for restaurants
# 16  Americans are poorly served by their grocery s...
# 17   Show HN: Fast Deep Reinforcement Learning Course
# 18                                          GPT-4chan
# 19  The last Howard Johnson's restaurant closes in...
# 20  Semantle: guess words based on Word2vec simila...
# 21   Brain-signal proteins evolved before animals did
# 22                     Software Library: MS-DOS Games
#
#                                                  link  votes
# 0               https://bert.org/2022/06/02/payphone/   1002
# 1                               https://vscodium.com/    657
# 2   https://hirrolot.github.io/posts/rust-is-hard-...    498
# 3                        https://www.webosarchive.com    405
# 4   https://www.tbray.org/ongoing/When/202x/2022/0...    308
# 5                            https://www.zkcrush.xyz/    279
# 6   https://ukdefencejournal.org.uk/classified-spe...    259
# 7   https://www.dcrainmaker.com/2022/05/shimano-fo...    246
# 8       https://www.jefftk.com/p/ceiling-air-purifier    245
# 9         https://itsallaboutthebit.com/async-simple/    226
# 10  https://www.epsilonsworld.com/2022/05/my-mega-...    209
# 11  https://blog.iconfactory.com/2022/06/worldwide...    201
# 12                                    https://yep.com    194
# 13  https://www.stat.berkeley.edu/~aldous/Real-Wor...    173
# 14  https://www.spamresource.com/2020/11/honestly-...    156
# 15  https://www.latimes.com/food/story/2022-06-02/...    151
# 16  https://www.economist.com/united-states/2022/0...    129
# 17          https://courses.dibya.online/p/fastdeeprl    128
# 18                             https://gpt-4chan.com/    119
# 19  https://www.washingtonpost.com/travel/2022/06/...    106
# 20                              https://semantle.com/    104
# 21  https://www.quantamagazine.org/brain-signal-pr...    103
# 22  https://archive.org/details/softwarelibrary_ms...    100

# %%
df['votes'].dtype
# Out:
# dtype('int64')

# %%
df['link'].dtype
# Out:
# dtype('O')

# %%
#to render links in the dataframe
from IPython.display import HTML
HTML(df.to_html(render_links=True, escape=False))
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>title</th>
#       <th>link</th>
#       <th>votes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>Installing a payphone in my house</td>
#       <td><a href="https://bert.org/2022/06/02/payphone/" target="_blank">https://bert.org/2022/06/02/payphone/</a></td>
#       <td>1002</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>VSCodium – Free/Libre Open Source Software Binaries of VS Code</td>
#       <td><a href="https://vscodium.com/" target="_blank">https://vscodium.com/</a></td>
#       <td>657</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>Rust Is Hard, Or: The Misery of Mainstream Programming</td>
#       <td><a href="https://hirrolot.github.io/posts/rust-is-hard-or-the-misery-of-mainstream-programming.html" target="_blank">https://hirrolot.github.io/posts/rust-is-hard-or-the-misery-of-mainstream-programming.html</a></td>
#       <td>498</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>Show HN: I restored Palm's webOS App Catalog, SDK and online help system</td>
#       <td><a href="https://www.webosarchive.com" target="_blank">https://www.webosarchive.com</a></td>
#       <td>405</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>Dangerous Gift</td>
#       <td><a href="https://www.tbray.org/ongoing/When/202x/2022/06/02/Dangerous-Gift" target="_blank">https://www.tbray.org/ongoing/When/202x/2022/06/02/Dangerous-Gift</a></td>
#       <td>308</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>Confess your love with zero-knowledge</td>
#       <td><a href="https://www.zkcrush.xyz/" target="_blank">https://www.zkcrush.xyz/</a></td>
#       <td>279</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>Classified specs leaked on War Thunder forum for third time</td>
#       <td><a href="https://ukdefencejournal.org.uk/classified-specs-leaked-on-war-thunder-forum-for-third-time/" target="_blank">https://ukdefencejournal.org.uk/classified-specs-leaked-on-war-thunder-forum-for-third-time/</a></td>
#       <td>259</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>Shimano Forces Hammerhead to Remove All Di2 Related Functionality From Karoo</td>
#       <td><a href="https://www.dcrainmaker.com/2022/05/shimano-forces-hammerhead-to-remove-all-di2-related-functionality-from-karoo.html" target="_blank">https://www.dcrainmaker.com/2022/05/shimano-forces-hammerhead-to-remove-all-di2-related-functionality-from-karoo.html</a></td>
#       <td>246</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>Ceiling Air Purifier</td>
#       <td><a href="https://www.jefftk.com/p/ceiling-air-purifier" target="_blank">https://www.jefftk.com/p/ceiling-air-purifier</a></td>
#       <td>245</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>Async Rust doesn't have to be hard</td>
#       <td><a href="https://itsallaboutthebit.com/async-simple/" target="_blank">https://itsallaboutthebit.com/async-simple/</a></td>
#       <td>226</td>
#     </tr>
#     <tr>
#       <th>10</th>
#       <td>My Mega65 has arrived</td>
#       <td><a href="https://www.epsilonsworld.com/2022/05/my-mega-65-has-arrived.html" target="_blank">https://www.epsilonsworld.com/2022/05/my-mega-65-has-arrived.html</a></td>
#       <td>209</td>
#     </tr>
#     <tr>
#       <th>11</th>
#       <td>WorldWideWeb.app</td>
#       <td><a href="https://blog.iconfactory.com/2022/06/worldwideweb-part-2/" target="_blank">https://blog.iconfactory.com/2022/06/worldwideweb-part-2/</a></td>
#       <td>201</td>
#     </tr>
#     <tr>
#       <th>12</th>
#       <td>Yep: Google alternative that shares revenue with creators – by Ahrefs</td>
#       <td><a href="https://yep.com" target="_blank">https://yep.com</a></td>
#       <td>194</td>
#     </tr>
#     <tr>
#       <th>13</th>
#       <td>40k coin tosses yield ambiguous evidence for dynamical bias</td>
#       <td><a href="https://www.stat.berkeley.edu/~aldous/Real-World/coin_tosses.html" target="_blank">https://www.stat.berkeley.edu/~aldous/Real-World/coin_tosses.html</a></td>
#       <td>173</td>
#     </tr>
#     <tr>
#       <th>14</th>
#       <td>Don't send to Gmail over IPv6</td>
#       <td><a href="https://www.spamresource.com/2020/11/honestly-dont-send-to-gmail-over-ipv6.html" target="_blank">https://www.spamresource.com/2020/11/honestly-dont-send-to-gmail-over-ipv6.html</a></td>
#       <td>156</td>
#     </tr>
#     <tr>
#       <th>15</th>
#       <td>What a gas stove ban means for restaurants</td>
#       <td><a href="https://www.latimes.com/food/story/2022-06-02/gas-stove-ban-chinese-korean-bbq-electric-new-buildings-restaurants-future" target="_blank">https://www.latimes.com/food/story/2022-06-02/gas-stove-ban-chinese-korean-bbq-electric-new-buildings-restaurants-future</a></td>
#       <td>151</td>
#     </tr>
#     <tr>
#       <th>16</th>
#       <td>Americans are poorly served by their grocery stores</td>
#       <td><a href="https://www.economist.com/united-states/2022/06/02/why-americans-are-poorly-served-by-their-grocery-stores" target="_blank">https://www.economist.com/united-states/2022/06/02/why-americans-are-poorly-served-by-their-grocery-stores</a></td>
#       <td>129</td>
#     </tr>
#     <tr>
#       <th>17</th>
#       <td>Show HN: Fast Deep Reinforcement Learning Course</td>
#       <td><a href="https://courses.dibya.online/p/fastdeeprl" target="_blank">https://courses.dibya.online/p/fastdeeprl</a></td>
#       <td>128</td>
#     </tr>
#     <tr>
#       <th>18</th>
#       <td>GPT-4chan</td>
#       <td><a href="https://gpt-4chan.com/" target="_blank">https://gpt-4chan.com/</a></td>
#       <td>119</td>
#     </tr>
#     <tr>
#       <th>19</th>
#       <td>The last Howard Johnson's restaurant closes in Lake George, N.Y.</td>
#       <td><a href="https://www.washingtonpost.com/travel/2022/06/02/last-howard-johnson-restaurant-closes/" target="_blank">https://www.washingtonpost.com/travel/2022/06/02/last-howard-johnson-restaurant-closes/</a></td>
#       <td>106</td>
#     </tr>
#     <tr>
#       <th>20</th>
#       <td>Semantle: guess words based on Word2vec similarity scores</td>
#       <td><a href="https://semantle.com/" target="_blank">https://semantle.com/</a></td>
#       <td>104</td>
#     </tr>
#     <tr>
#       <th>21</th>
#       <td>Brain-signal proteins evolved before animals did</td>
#       <td><a href="https://www.quantamagazine.org/brain-signal-proteins-evolved-before-animals-did-20220603/" target="_blank">https://www.quantamagazine.org/brain-signal-proteins-evolved-before-animals-did-20220603/</a></td>
#       <td>103</td>
#     </tr>
#     <tr>
#       <th>22</th>
#       <td>Software Library: MS-DOS Games</td>
#       <td><a href="https://archive.org/details/softwarelibrary_msdos_games" target="_blank">https://archive.org/details/softwarelibrary_msdos_games</a></td>
#       <td>100</td>
#     </tr>
#   </tbody>
# </table>

# %%
df['title'].dtype
# Out:
# dtype('O')

# %%
## convert the df to csv file
df.to_csv('file.csv')
